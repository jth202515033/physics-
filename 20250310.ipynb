# %% [markdown]
# <a href="https://colab.research.google.com/github/jth202515033/physics-/blob/20250312/20250310.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import math #수학 함수를 사용하기 위해서 라이브러리 추가

# %% [markdown]
# 호도법

# %%
angle_degree = 30

angle_radian = angle_degree * math.pi / 180

print("angle_radian : ",angle_radian )
# Out:
# angle_radian :  0.5235987755982988

# %%
math.cos(angle_radian)
# Out:
# 0.8660254037844387

# %%
math.sin(angle_radian)
# Out:
# 0.49999999999999994

# %%
math.tan(angle_radian)
# Out:
# 0.5773502691896257

# %% [markdown]
# 직교 좌표를 극좌표로 변환

# %%
x,y = 1.0, 2.0

# %%
r = math.sqrt(x**2 + y**2)
theta_raidan = math.atan2(y,x )

print(r, theta_raidan)
# Out:
# 2.23606797749979 1.1071487177940904

# %% [markdown]
# 극좌표를 직교 좌표로 변환

# %%
r= 10
angle_radian= 30
angle_radian = math.radians(angle)

# %%
x = r * math.cos(angle_radian)
y = r * math.sin(angle_radian)

print(x,y)
# Out:
# 8.660254037844387 4.999999999999999
